# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
onepiece=[('Luffy','nika'),
          ('Kaido','Uo Uo'),
          ('Teach','Yami yami')]

# %%
jolly=['shp','hyajuku','bb']

# %%
onepiece=pd.DataFrame(onepiece,columns=['Name','DF'])
jolly=pd.DataFrame(jolly,columns=['jolly'])

# %%
onepiece
# Out:
#     Name         DF
# 0  Luffy       nika
# 1  Kaido      Uo Uo
# 2  Teach  Yami yami

# %%
jolly
# Out:
#      jolly
# 0      shp
# 1  hyajuku
# 2       bb

# %%
char=pd.concat([onepiece,jolly],axis=1)
char
# Out:
#     Name         DF    jolly
# 0  Luffy       nika      shp
# 1  Kaido      Uo Uo  hyajuku
# 2  Teach  Yami yami       bb

# %%
char2=pd.concat([onepiece,jolly],axis=0,keys=['char','jolly'])
char2
# Out:
#           Name         DF    jolly
# char  0  Luffy       nika      NaN
#       1  Kaido      Uo Uo      NaN
#       2  Teach  Yami yami      NaN
# jolly 0    NaN        NaN      shp
#       1    NaN        NaN  hyajuku
#       2    NaN        NaN       bb

# %%
shp=[('Luffy','Captain'),
     ('Zoro','Swordsman'),
     ('Sanji','Cook'),
     ('Nami','Navigator'),
     ('Ussop','sniper'),
     ]

# %%
df=['nika','none','none','none','none']

# %%
df=pd.DataFrame(df,columns=['df'])
df
# Out:
#      df
# 0  nika
# 1  none
# 2  none
# 3  none
# 4  none

# %%
shp=pd.DataFrame(shp,columns=['Name','Captain'])
shp
# Out:
#     Name    Captain
# 0  Luffy    Captain
# 1   Zoro  Swordsman
# 2  Sanji       Cook
# 3   Nami  Navigator
# 4  Ussop     sniper

# %%
krushp=pd.concat([df,shp],axis=1,keys=['df','kru'])
krushp
# Out:
#      df    kru
#      df   Name    Captain
# 0  nika  Luffy    Captain
# 1  none   Zoro  Swordsman
# 2  none  Sanji       Cook
# 3  none   Nami  Navigator
# 4  none  Ussop     sniper
