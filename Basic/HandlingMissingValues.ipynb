# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df=pd.read_csv('weather_data.csv',parse_dates=['day'])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df=df.set_index(df['day'])
df
# Out:
#                   day  temperature  windspeed   event
# day
# 2017-01-01 2017-01-01         32.0        6.0    Rain
# 2017-01-04 2017-01-04          NaN        9.0   Sunny
# 2017-01-05 2017-01-05         28.0        NaN    Snow
# 2017-01-06 2017-01-06          NaN        7.0     NaN
# 2017-01-07 2017-01-07         32.0        NaN    Rain
# 2017-01-08 2017-01-08          NaN        NaN   Sunny
# 2017-01-09 2017-01-09          NaN        NaN     NaN
# 2017-01-10 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11 2017-01-11         40.0       12.0   Sunny

# %%
newdf=df.fillna(0)
newdf
# Out:
#                   day  temperature  windspeed   event
# day
# 2017-01-01 2017-01-01         32.0        6.0    Rain
# 2017-01-04 2017-01-04          0.0        9.0   Sunny
# 2017-01-05 2017-01-05         28.0        0.0    Snow
# 2017-01-06 2017-01-06          0.0        7.0       0
# 2017-01-07 2017-01-07         32.0        0.0    Rain
# 2017-01-08 2017-01-08          0.0        0.0   Sunny
# 2017-01-09 2017-01-09          0.0        0.0       0
# 2017-01-10 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11 2017-01-11         40.0       12.0   Sunny

# %%
newdf1=df.fillna({
    'temperature':0.,
    'windspeed':0,
    'event':'no event'
})
newdf1
# Out:
#                   day  temperature  windspeed     event
# day
# 2017-01-01 2017-01-01         32.0        6.0      Rain
# 2017-01-04 2017-01-04          0.0        9.0     Sunny
# 2017-01-05 2017-01-05         28.0        0.0      Snow
# 2017-01-06 2017-01-06          0.0        7.0  no event
# 2017-01-07 2017-01-07         32.0        0.0      Rain
# 2017-01-08 2017-01-08          0.0        0.0     Sunny
# 2017-01-09 2017-01-09          0.0        0.0  no event
# 2017-01-10 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11 2017-01-11         40.0       12.0     Sunny

# %%
newdf3=df.fillna(method='bfill')
newdf3
# Out:
# <ipython-input-92-e1de1af93efc>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   newdf3=df.fillna(method='bfill')
#                   day  temperature  windspeed   event
# day
# 2017-01-01 2017-01-01         32.0        6.0    Rain
# 2017-01-04 2017-01-04         28.0        9.0   Sunny
# 2017-01-05 2017-01-05         28.0        7.0    Snow
# 2017-01-06 2017-01-06         32.0        7.0    Rain
# 2017-01-07 2017-01-07         32.0        8.0    Rain
# 2017-01-08 2017-01-08         34.0        8.0   Sunny
# 2017-01-09 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11 2017-01-11         40.0       12.0   Sunny

# %%
newdf4=df.fillna(method='ffill')
newdf4
# Out:
# <ipython-input-93-0b1a3a96997a>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   newdf4=df.fillna(method='ffill')
#                   day  temperature  windspeed   event
# day
# 2017-01-01 2017-01-01         32.0        6.0    Rain
# 2017-01-04 2017-01-04         32.0        9.0   Sunny
# 2017-01-05 2017-01-05         28.0        9.0    Snow
# 2017-01-06 2017-01-06         28.0        7.0    Snow
# 2017-01-07 2017-01-07         32.0        7.0    Rain
# 2017-01-08 2017-01-08         32.0        7.0   Sunny
# 2017-01-09 2017-01-09         32.0        7.0   Sunny
# 2017-01-10 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11 2017-01-11         40.0       12.0   Sunny

# %%
newdf5=df.fillna(method='bfill',limit=1)
newdf5
# Out:
# <ipython-input-94-6a9a4de07b9c>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   newdf5=df.fillna(method='bfill',limit=1)
#                   day  temperature  windspeed   event
# day
# 2017-01-01 2017-01-01         32.0        6.0    Rain
# 2017-01-04 2017-01-04         28.0        9.0   Sunny
# 2017-01-05 2017-01-05         28.0        7.0    Snow
# 2017-01-06 2017-01-06         32.0        7.0    Rain
# 2017-01-07 2017-01-07         32.0        NaN    Rain
# 2017-01-08 2017-01-08          NaN        NaN   Sunny
# 2017-01-09 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11 2017-01-11         40.0       12.0   Sunny

# %%
newdf6=df.fillna(method='ffill',limit=1)
newdf6
# Out:
# <ipython-input-96-828e64caa36c>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   newdf6=df.fillna(method='ffill',limit=1)
#                   day  temperature  windspeed   event
# day
# 2017-01-01 2017-01-01         32.0        6.0    Rain
# 2017-01-04 2017-01-04         32.0        9.0   Sunny
# 2017-01-05 2017-01-05         28.0        9.0    Snow
# 2017-01-06 2017-01-06         28.0        7.0    Snow
# 2017-01-07 2017-01-07         32.0        7.0    Rain
# 2017-01-08 2017-01-08         32.0        NaN   Sunny
# 2017-01-09 2017-01-09          NaN        NaN   Sunny
# 2017-01-10 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#                   day  temperature  windspeed   event
# day
# 2017-01-01 2017-01-01         32.0        6.0    Rain
# 2017-01-04 2017-01-04          NaN        9.0   Sunny
# 2017-01-05 2017-01-05         28.0        NaN    Snow
# 2017-01-06 2017-01-06          NaN        7.0     NaN
# 2017-01-07 2017-01-07         32.0        NaN    Rain
# 2017-01-08 2017-01-08          NaN        NaN   Sunny
# 2017-01-09 2017-01-09          NaN        NaN     NaN
# 2017-01-10 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11 2017-01-11         40.0       12.0   Sunny

# %%
newdf7=df.interpolate('linear')
newdf7
# Out:
# <ipython-input-104-f2305d3b65d6>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   newdf7=df.interpolate('linear')
#                   day  temperature  windspeed   event
# day
# 2017-01-01 2017-01-01    32.000000       6.00    Rain
# 2017-01-04 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05 2017-01-05    28.000000       8.00    Snow
# 2017-01-06 2017-01-06    30.000000       7.00     NaN
# 2017-01-07 2017-01-07    32.000000       7.25    Rain
# 2017-01-08 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09 2017-01-09    33.333333       7.75     NaN
# 2017-01-10 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11 2017-01-11    40.000000      12.00   Sunny

# %%
newdf8=df.dropna()
newdf8
# Out:
#                   day  temperature  windspeed   event
# day
# 2017-01-01 2017-01-01         32.0        6.0    Rain
# 2017-01-10 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11 2017-01-11         40.0       12.0   Sunny

# %%
new_df9 = df.dropna(thresh=2)
new_df9
# Out:
#                   day  temperature  windspeed   event
# day
# 2017-01-01 2017-01-01         32.0        6.0    Rain
# 2017-01-04 2017-01-04          NaN        9.0   Sunny
# 2017-01-05 2017-01-05         28.0        NaN    Snow
# 2017-01-06 2017-01-06          NaN        7.0     NaN
# 2017-01-07 2017-01-07         32.0        NaN    Rain
# 2017-01-08 2017-01-08          NaN        NaN   Sunny
# 2017-01-10 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11 2017-01-11         40.0       12.0   Sunny
